# %%
# load all packages
from docx import *
import pandas as pd
import numpy as np
import os
import nltk
# nltk.download('popular')
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.metrics.pairwise import cosine_similarity 
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk import ne_chunk
from textblob import TextBlob
from textblob import Word

# %%
# extract cells
full_data = pd.read_excel('test_code.xlsx')
df_length = len(full_data)
data = pd.DataFrame()

for i in range(0, df_length):
    data = data.append({'par_#': i + 1, 'text': (full_data.iloc[i, 19])}, ignore_index = True)
data.head(7)
# Out:
#    par_#                                               text
# 0    1.0  This seemed to me too profound a joke to be in...
# 1    2.0                              "My nature is subdued
# 2    3.0         To what it works in, like the dyer's hand:
# 3    4.0           Pity me, then, and wish I were renewed!"
# 4    5.0  But as it is wholesome that the parsimonious p...
# 5    6.0  There is only one other point on which I offer...
# 6    7.0  In Bleak House I have purposely dwelt upon the...

# %%
# pre-processing
# turn into lower case
data['text'] = data['text'].apply(lambda x: " ".join(x.lower() for x in x.split()))
data.head(7)
# Out:
#    par_#                                               text
# 0    1.0  this seemed to me too profound a joke to be in...
# 1    2.0                              "my nature is subdued
# 2    3.0         to what it works in, like the dyer's hand:
# 3    4.0           pity me, then, and wish i were renewed!"
# 4    5.0  but as it is wholesome that the parsimonious p...
# 5    6.0  there is only one other point on which i offer...
# 6    7.0  in bleak house i have purposely dwelt upon the...

# %%
# pre-processing
# remove punctuation
# ^ specifies NOT to match that group or set
# \s is whitespace characters
# \w is alphanumeric character
data['text'] = data['text'].str.replace('[^\w\s]', '')
data.head(7)
# Out:
#    interview_#                                               text
# 0          1.0                                        in chancery
# 1          2.0  london michaelmas term lately over and the lor...
# 2          3.0  fog everywhere fog up the river where it flows...
# 3          4.0  gas looming through the fog in divers places i...
# 4          5.0  the raw afternoon is rawest and the dense fog ...
# 5          6.0  never can there come fog too thick never can t...
# 6          7.0  on such an afternoon if ever the lord high cha...

# %%
# pre-processing
# remove stop words (commonly used words: the, a, an, in)
stop = stopwords.words('english')
data['text'] = data['text'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))
data.head(7)
# Out:
#    par_#                                               text
# 0    1.0  seemed profound joke inserted body book restor...
# 1    2.0                                 "my nature subdued
# 2    3.0                        works in, like dyer's hand:
# 3    4.0                      pity me, then, wish renewed!"
# 4    5.0  wholesome parsimonious public know doing, stil...
# 5    6.0  one point offer word remark. possibility calle...
# 6    7.0  bleak house purposely dwelt upon romantic side...

# %%
data['text'] = data['text'].apply(lambda x: " ".join(x for x in x.split() if x not in ['ms', 'mc']))
data.head(7)
# Out:
#    par_#                                               text
# 0    1.0  seemed profound joke inserted body book restor...
# 1    2.0                                 "my nature subdued
# 2    3.0                        works in, like dyer's hand:
# 3    4.0                      pity me, then, wish renewed!"
# 4    5.0  wholesome parsimonious public know doing, stil...
# 5    6.0  one point offer word remark. possibility calle...
# 6    7.0  bleak house purposely dwelt upon romantic side...

# %%
# pre-processing
# rare words removal - remove all words that only show up one time

freq = pd.Series(''.join(data['text']).split()).value_counts()[-22386:]
freq
# Out:
# crouches         1
# donnys           1
# proceeding.      1
# moaned           1
# connivance,      1
#                 ..
# impartially      1
# compelling       1
# pleases          1
# neck-kerchief    1
# away."my         1
# Length: 22386, dtype: int64

# %%
data['text'] = data['text'].apply(lambda x: " ".join(y for y in x.split() if y not in freq))
data
# Out:
#        par_#                                               text
# 0        1.0  seemed profound joke body book restored conver...
# 1        2.0                                 "my nature subdued
# 2        3.0                               works in, like hand:
# 3        4.0                      pity me, then, wish renewed!"
# 4        5.0  wholesome parsimonious public know doing, stil...
# ...      ...                                                ...
# 7172  7173.0                                        "such were,
# 7173  7174.0  "my dear dame durden," said allan, drawing arm...
# 7174  7175.0                             "you know do; see it."
# 7175  7176.0                     "and know prettier ever were?"
# 7176  7177.0  "i know that; certain know now. know dearest l...
#
# [7177 rows x 2 columns]

# %%
# pre-processing
# lemmatization, convert words into root words
## MT - This seems to do the same thing as the kernel 2 above this one
data['text'] = data['text'].apply(lambda x: " ".join([Word(y).lemmatize() for y in x.split()]))
data
# Out:
#        par_#                                               text
# 0        1.0  seemed profound joke body book restored conver...
# 1        2.0                                 "my nature subdued
# 2        3.0                                work in, like hand:
# 3        4.0                      pity me, then, wish renewed!"
# 4        5.0  wholesome parsimonious public know doing, stil...
# ...      ...                                                ...
# 7172  7173.0                                        "such were,
# 7173  7174.0  "my dear dame durden," said allan, drawing arm...
# 7174  7175.0                             "you know do; see it."
# 7175  7176.0                     "and know prettier ever were?"
# 7176  7177.0  "i know that; certain know now. know dearest l...
#
# [7177 rows x 2 columns]

# %%
## MT - With words: Tokenize, add POS tags (list), turn to trees with `ne_chunk`, create array of chunks with allChunks
allChunks = []
for i in data['text']:
    token = word_tokenize(i)
    tags = nltk.pos_tag(token)
    chunk = ne_chunk(tags)
    allChunks.append(chunk)
allChunks
# Out:
# [Tree('S', [('seemed', 'VBN'), ('profound', 'JJ'), ('joke', 'NN'), ('body', 'NN'), ('book', 'NN'), ('restored', 'VBD'), ('conversation', 'NN'), ('kenge', 'NN'), ('mr.', 'NN'), ('vholes', 'NNS'), (',', ','), ('one', 'CD'), ('think', 'NN'), ('must', 'MD'), ('might', 'MD'), ('coupled', 'VB'), ('apt', 'JJ'), ('one', 'CD'), ('sonnets', 'NNS'), (':', ':')]),
#  Tree('S', [('``', '``'), ('my', 'PRP$'), ('nature', 'NN'), ('subdued', 'VBD')]),
#  Tree('S', [('work', 'NN'), ('in', 'IN'), (',', ','), ('like', 'IN'), ('hand', 'NN'), (':', ':')]),
#  Tree('S', [('pity', 'NN'), ('me', 'PRP'), (',', ','), ('then', 'RB'), (',', ','), ('wish', 'JJ'), ('renewed', 'VBN'), ('!', '.'), ("''", "''")]),
#  Tree('S', [('wholesome', 'RB'), ('parsimonious', 'JJ'), ('public', 'NN'), ('know', 'VBP'), ('doing', 'VBG'), (',', ','), ('still', 'RB'), ('doing', 'VBG'), (',', ','), ('connexion', 'NN'), (',', ','), ('mention', 'NN'), ('everything', 'NN'), ('set', 'VBN'), ('forth', 'JJ'), ('page', 'NN'), ('concerning', 'VBG'), ('court', 'NN'), ('chancery', 'NN'), ('true', 'JJ'), (',', ','), ('within', 'IN'), ('truth', 'NN'), ('.', '.'), ('case', 'NN'), ('gridley', 'JJ'), ('essential', 'JJ'), ('altered', 'VBD'), ('one', 'CD'), ('actual', 'JJ'), ('made', 'VBN'), ('public', 'NN'), ('disinterested', 'VBD'), ('person', 'NN'), ('professionally', 'RB'), ('acquainted', 'VBD'), ('whole', 'JJ'), ('monstrous', 'JJ'), ('wrong', 'JJ'), ('beginning', 'VBG'), ('end', 'NN'), ('.', '.'), ('present', 'JJ'), ('moment', 'NN'), ('suit', 'NN'), ('court', 'NN'), ('commenced', 'VBD'), ('nearly', 'RB'), ('twenty', 'JJ'), ('year', 'NN'), ('ago', 'RB'), (',', ','), ('thirty', 'JJ'), ('forty', 'JJ'), ('counsel', 'NN'), ('known', 'VBN'), ('appear', 'IN'), ('one', 'CD'), ('time', 'NN'), (',', ','), ('cost', 'NN'), ('incurred', 'JJ'), ('amount', 'NN'), ('seventy', 'NN'), ('thousand', 'CD'), ('pounds', 'NNS'), (',', ','), ('friendly', 'JJ'), ('suit', 'NN'), (',', ','), ('(', '('), ('i', 'JJ'), ('nearer', 'VBP'), ('termination', 'NN'), ('begun', 'VBN'), ('.', '.'), ('another', 'DT'), ('suit', 'NN'), ('chancery', 'NN'), (',', ','), ('yet', 'RB'), ('decided', 'VBN'), (',', ','), ('commenced', 'VBD'), ('close', 'JJ'), ('last', 'JJ'), ('century', 'NN'), ('double', 'JJ'), ('amount', 'NN'), ('seventy', 'NN'), ('thousand', 'CD'), ('pound', 'NN'), ('swallowed', 'VBD'), ('costs', 'NNS'), ('.', '.'), ('wanted', 'JJ'), ('authority', 'NN'), ('jarndyce', 'NN'), ('jarndyce', 'NN'), (',', ','), ('could', 'MD'), ('rain', 'VB'), ('pages', 'NNS'), (',', ','), ('shame', 'VBP'), ('parsimonious', 'JJ'), ('public', 'NN'), ('.', '.')]),
#  Tree('S', [('one', 'CD'), ('point', 'NN'), ('offer', 'NN'), ('word', 'NN'), ('remark', 'NN'), ('.', '.'), ('possibility', 'NN'), ('called', 'VBN'), ('spontaneous', 'JJ'), ('combustion', 'NN'), ('denied', 'VBD'), ('since', 'IN'), ('death', 'NN'), Tree('PERSON', [('mr.', 'NN'), ('krook', 'NNP')]), (';', ':'), ('good', 'JJ'), ('friend', 'NN'), Tree('PERSON', [('mr.', 'NN'), ('mistaken', 'NNP')]), (',', ','), ('soon', 'RB'), ('found', 'VBD'), (',', ','), ('supposing', 'VBG'), ('thing', 'NN'), ('abandoned', 'VBD'), ('published', 'VBN'), ('ingenious', 'JJ'), ('letter', 'NN'), ('time', 'NN'), ('event', 'NN'), ('chronicled', 'VBD'), (',', ','), ('arguing', 'VBG'), ('spontaneous', 'JJ'), ('combustion', 'NN'), ('could', 'MD'), ('possibly', 'RB'), ('be', 'VB'), ('.', '.'), ('need', 'VB'), ('observe', 'VBP'), ('negligently', 'RB'), ('reader', 'JJR'), ('wrote', 'VBD'), ('description', 'NN'), ('took', 'VBD'), ('pain', 'NN'), ('investigate', 'NN'), ('subject', 'NN'), ('.', '.'), ('thirty', 'NN'), ('case', 'NN'), ('record', 'NN'), (',', ','), ('famous', 'JJ'), (',', ','), ('countess', 'JJ'), ('cornelia', 'NN'), ('de', 'IN'), ('baudi', 'FW'), ('minutely', 'RB'), ('described', 'VBN'), ('bianchini', 'NN'), (',', ','), ('prebendary', 'JJ'), ('verona', 'NN'), (',', ','), ('otherwise', 'RB'), ('distinguished', 'JJ'), ('letters', 'NNS'), (',', ','), ('published', 'VBN'), ('account', 'NN'), ('afterwards', 'NNS'), ('appearances', 'NNS'), (',', ','), ('beyond', 'IN'), ('rational', 'JJ'), ('doubt', 'NN'), (',', ','), ('observed', 'VBD'), ('case', 'NN'), ('appearance', 'NN'), ('observed', 'VBD'), Tree('PERSON', [('mr.', 'JJ')]), ('krook', 'NNP'), ("'s", 'POS'), ('case', 'NN'), ('.', '.'), ('next', 'JJ'), ('famous', 'JJ'), ('instance', 'NN'), ('happened', 'VBD'), ('six', 'CD'), ('year', 'NN'), ('case', 'NN'), ('le', 'NN'), ('cat', 'NN'), (',', ','), ('one', 'CD'), ('surgeon', 'NN'), ('produced', 'VBN'), ('france', 'NN'), ('.', '.'), ('subject', 'JJ'), ('woman', 'NN'), (',', ','), ('whose', 'WP$'), ('husband', 'NN'), ('convicted', 'VBD'), ('murdered', 'VBD'), ('her', 'PRP'), (';', ':'), ('solemn', 'VB'), ('appeal', 'NN'), ('higher', 'JJR'), ('court', 'NN'), (',', ','), ('acquitted', 'VBD'), ('shown', 'VBN'), ('upon', 'IN'), ('evidence', 'NN'), ('died', 'VBD'), ('death', 'NN'), ('name', 'NN'), ('spontaneous', 'JJ'), ('combustion', 'NN'), ('given', 'VBN'), ('.', '.'), ('think', 'VB'), ('necessary', 'JJ'), ('add', 'NN'), ('facts', 'NNS'), (',', ','), ('general', 'JJ'), ('reference', 'NN'), ('authority', 'NN'), ('found', 'VBD'), ('page', 'NN'), ('recorded', 'VBN'), ('opinion', 'NN'), ('distinguished', 'VBN'), ('medical', 'JJ'), ('french', 'JJ'), (',', ','), ('english', 'JJ'), (',', ','), ('days', 'NNS'), (',', ','), ('observing', 'VBG'), ('shall', 'MD'), ('abandon', 'VB'), ('fact', 'NN'), ('shall', 'MD'), ('considerable', 'VB'), ('spontaneous', 'JJ'), ('combustion', 'NN'), ('testimony', 'NN'), ('human', 'JJ'), ('occurrence', 'NN'), ('usually', 'RB'), ('received', 'VBN'), ('.', '.'), ('*', 'CD'), ('*', 'NN')]),
#  Tree('S', [('bleak', 'JJ'), ('house', 'NN'), ('purposely', 'RB'), ('dwelt', 'VBD'), ('upon', 'JJ'), ('romantic', 'JJ'), ('side', 'NN'), ('familiar', 'JJ'), ('things', 'NNS'), ('.', '.')]),
#  Tree('S', [('london', 'NN'), ('.', '.'), ('michaelmas', 'JJ'), ('term', 'NN'), ('lately', 'RB'), ('over', 'IN'), (',', ','), ('lord', 'JJ'), ('chancellor', 'NN'), ('sitting', 'VBG'), ('lincoln', 'NN'), ("'s", 'POS'), ('inn', 'NN'), ('hall', 'NN'), ('.', '.'), ('implacable', 'JJ'), ('november', 'JJ'), ('weather', 'NN'), ('.', '.'), ('much', 'JJ'), ('mud', 'NN'), ('street', 'NN'), ('water', 'NN'), ('newly', 'RB'), ('retired', 'VBD'), ('face', 'NN'), ('earth', 'NN'), (',', ','), ('would', 'MD'), ('wonderful', 'VB'), ('meet', 'VB'), ('forty', 'JJ'), ('foot', 'NN'), ('long', 'RB'), ('so', 'RB'), (',', ','), ('waddling', 'VBG'), ('like', 'IN'), ('hill', 'NN'), ('.', '.'), ('smoke', 'NN'), ('lowering', 'VBG'), ('making', 'VBG'), ('soft', 'JJ'), ('black', 'JJ'), ('flake', 'NN'), ('soot', 'NN'), ('mourning', 'NN'), (',', ','), ('one', 'CD'), ('might', 'MD'), ('imagine', 'VB'), (',', ','), ('death', 'NN'), ('sun', 'NN'), ('.', '.'), ('dogs', 'NNS'), (',', ','), ('horses', 'NNS'), (',', ','), ('scarcely', 'RB'), ('better', 'RBR'), (';', ':'), ('splashed', 'JJ'), ('foot', 'NN'), ('jostling', 'VBG'), ('one', 'CD'), ('another', 'DT'), ("'s", 'POS'), ('general', 'JJ'), ('infection', 'NN'), ('ill', 'NN'), ('temper', 'NN'), (',', ','), ('losing', 'VBG'), ('ten', 'CD'), ('thousand', 'JJ'), ('foot', 'NN'), ('passenger', 'NN'), ('slipping', 'VBG'), ('sliding', 'VBG'), ('since', 'IN'), ('day', 'NN'), ('broke', 'VBD'), ('(', '('), ('if', 'IN'), ('day', 'NN'), ('ever', 'RB'), ('adding', 'VBG'), ('new', 'JJ'), ('deposit', 'NN'), ('crust', 'NN'), ('upon', 'IN'), ('crust', 'NN'), ('mud', 'NN'), (',', ','), ('sticking', 'VBG'), ('point', 'NN'), ('pavement', 'NN'), (',', ','), ('compound', 'NN'), ('interest', 'NN'), ('.', '.')]),
#  Tree('S', [('fog', 'NN'), ('everywhere', 'RB'), ('.', '.'), ('fog', 'JJ'), ('river', 'NN'), (',', ','), ('flow', 'NN'), ('among', 'IN'), ('green', 'JJ'), ('fog', 'NN'), ('river', 'NN'), (',', ','), ('roll', 'NN'), ('among', 'IN'), ('tier', 'JJ'), ('shipping', 'VBG'), ('great', 'JJ'), ('(', '('), ('and', 'CC'), ('city', 'NN'), ('.', '.'), ('fog', 'JJ'), ('marshes', 'NNS'), (',', ','), ('fog', 'JJ'), ('kentish', 'JJ'), ('fog', 'NN'), ('creeping', 'VBG'), ('fog', 'JJ'), ('lying', 'VBG'), ('yard', 'RB'), ('hovering', 'VBG'), ('great', 'JJ'), ('fog', 'JJ'), ('drooping', 'VBG'), ('small', 'JJ'), ('fog', 'NNS'), ('eye', 'NN'), ('throat', 'NN'), ('ancient', 'NN'), ('fog', 'NN'), ('bowl', 'NN'), ('afternoon', 'NN'), ('pipe', 'NN'), ('wrathful', 'JJ'), ('close', 'RB'), ('fog', 'JJ'), ('pinching', 'NN'), ('finger', 'NN'), ('shivering', 'VBG'), ('little', 'JJ'), ('boy', 'JJ'), ('chance', 'NN'), ('people', 'NNS'), ('bridge', 'VBP'), ('peeping', 'VBG'), ('sky', 'NN'), ('fog', 'NN'), (',', ','), ('fog', 'VBP'), ('round', 'VB'), ('them', 'PRP'), (',', ','), ('hanging', 'VBG'), ('misty', 'NN'), ('clouds', 'NNS'), ('.', '.')]),
#  Tree('S', [('gas', 'NN'), ('looming', 'VBG'), ('fog', 'JJ'), ('diver', 'JJ'), ('place', 'NN'), ('streets', 'NNS'), (',', ','), ('much', 'JJ'), ('sun', 'NN'), ('may', 'MD'), (',', ','), ('fields', 'NNS'), (',', ','), ('seen', 'VBN'), ('loom', 'NN'), ('shop', 'NN'), ('lighted', 'VBD'), ('two', 'CD'), ('hour', 'NN'), ('time—as', 'NN'), ('gas', 'NN'), ('seems', 'VBZ'), ('know', 'VBP'), (',', ','), ('haggard', 'JJ'), ('unwilling', 'JJ'), ('look', 'NN'), ('.', '.')]),
#  Tree('S', [('raw', 'JJ'), ('afternoon', 'NN'), ('dense', 'NN'), ('fog', 'NN'), ('muddy', 'NNP'), ('street', 'NN'), ('near', 'IN'), ('leaden-headed', 'JJ'), ('old', 'JJ'), ('obstruction', 'NN'), (',', ','), ('appropriate', 'JJ'), ('ornament', 'NN'), ('threshold', 'VBD'), ('leaden-headed', 'JJ'), ('old', 'JJ'), ('temple', 'NN'), ('bar', 'NN'), ('.', '.'), ('hard', 'JJ'), ('temple', 'NN'), ('bar', 'NN'), (',', ','), ('lincoln', 'NN'), ("'s", 'POS'), ('inn', 'NN'), ('hall', 'NN'), (',', ','), ('heart', 'NN'), ('fog', 'NN'), (',', ','), ('sits', 'VBZ'), ('lord', 'RB'), ('high', 'JJ'), ('chancellor', 'NN'), ('high', 'JJ'), ('court', 'NN'), ('chancery', 'NN'), ('.', '.')]),
#  Tree('S', [('never', 'RB'), ('come', 'VBN'), ('fog', 'NN'), ('thick', 'NN'), (',', ','), ('never', 'RB'), ('come', 'VBN'), ('mud', 'NN'), ('mire', 'NN'), ('deep', 'NN'), (',', ','), ('groping', 'VBG'), ('condition', 'NN'), ('high', 'JJ'), ('court', 'NN'), ('chancery', 'NN'), (',', ','), ('pestilent', 'JJ'), ('hold', 'NN'), ('day', 'NN'), ('sight', 'VBD'), ('heaven', 'RB'), ('earth', 'JJ'), ('.', '.')]),
#  Tree('S', [('afternoon', 'NN'), (',', ','), ('ever', 'RB'), (',', ','), ('lord', 'JJ'), ('high', 'JJ'), ('chancellor', 'NN'), ('ought', 'MD'), ('sitting', 'VBG'), ('foggy', 'JJ'), ('glory', 'NN'), ('round', 'NN'), ('head', 'NN'), (',', ','), ('softly', 'RB'), ('fenced', 'VBD'), ('crimson', 'JJ'), ('cloth', 'NN'), ('curtains', 'NNS'), (',', ','), ('addressed', 'VBD'), ('large', 'JJ'), ('great', 'JJ'), ('whiskers', 'NNS'), (',', ','), ('little', 'JJ'), ('voice', 'NN'), (',', ','), ('interminable', 'JJ'), ('brief', 'NN'), (',', ','), ('outwardly', 'RB'), ('directing', 'VBG'), ('contemplation', 'NN'), ('lantern', 'JJ'), ('roof', 'NN'), (',', ','), ('see', 'VBP'), ('nothing', 'NN'), ('fog', 'NN'), ('.', '.'), ('afternoon', 'NN'), ('score', 'NN'), ('member', 'NN'), ('high', 'JJ'), ('court', 'NN'), ('chancery', 'NN'), ('bar', 'NN'), ('ought', 'MD'), ('be—as', 'VB'), ('engaged', 'VBD'), ('one', 'CD'), ('ten', 'NN'), ('thousand', 'CD'), ('stage', 'NN'), ('endless', 'NN'), ('cause', 'NN'), (',', ','), ('tripping', 'VBG'), ('one', 'CD'), ('another', 'DT'), ('slippery', 'NN'), ('groping', 'VBG'), ('running', 'VBG'), ('horsehair', 'NN'), ('head', 'NN'), ('wall', 'NN'), ('word', 'NN'), ('making', 'VBG'), ('pretence', 'NN'), ('equity', 'NN'), ('serious', 'JJ'), ('faces', 'VBZ'), (',', ','), ('might', 'MD'), ('.', '.'), ('afternoon', 'NN'), ('various', 'JJ'), ('solicitor', 'NN'), ('cause', 'NN'), (',', ','), ('two', 'CD'), ('three', 'CD'), ('inherited', 'VBN'), ('made', 'VBN'), ('fortune', 'NN'), ('it', 'PRP'), (',', ','), ('ought', 'MD'), ('be—as', 'VB'), ('line', 'NN'), (',', ','), ('long', 'RB'), ('well', 'RB'), ('(', '('), ('but', 'CC'), ('might', 'MD'), ('look', 'VB'), ('vain', 'JJ'), ('truth', 'NN'), ('bottom', 'IN'), ('it', 'PRP'), (')', ')'), ('red', 'VBD'), ('table', 'JJ'), ('silk', 'NN'), ('bills', 'NNS'), (',', ','), ('answers', 'NNS'), (',', ','), ('injunctions', 'NNS'), (',', ','), ('affidavits', 'NNS'), (',', ','), ('reference', 'NN'), ('mountain', 'NN'), ('nonsense', 'NN'), (',', ','), ('piled', 'VBD'), ('them', 'PRP'), ('.', '.'), ('well', 'RB'), ('may', 'MD'), ('court', 'NN'), ('dim', 'NN'), (',', ','), ('wasting', 'VBG'), ('candle', 'NN'), ('there', 'RB'), (';', ':'), ('well', 'RB'), ('may', 'MD'), ('fog', 'VB'), ('hang', 'JJR'), ('heavy', 'NN'), ('it', 'PRP'), (',', ','), ('would', 'MD'), ('never', 'RB'), ('get', 'VB'), ('out', 'RP'), (';', ':'), ('well', 'RB'), ('may', 'MD'), ('window', 'VB'), ('lose', 'VB'), ('colour', 'JJ'), ('admit', 'NN'), ('light', 'JJ'), ('day', 'NN'), ('place', 'NN'), (';', ':'), ('well', 'RB'), ('may', 'MD'), ('uninitiated', 'JJ'), ('streets', 'NNS'), (',', ','), ('peep', 'JJ'), ('glass', 'NN'), ('pane', 'NN'), ('door', 'NN'), (',', ','), ('deterred', 'VBD'), ('entrance', 'JJ'), ('owlish', 'JJ'), ('aspect', 'NN'), ('drawl', 'NN'), (',', ','), ('languidly', 'RB'), ('echoing', 'VBG'), ('roof', 'NN'), ('padded', 'VBD'), ('lord', 'RB'), ('high', 'JJ'), ('chancellor', 'NN'), ('look', 'NN'), ('lantern', 'JJ'), ('light', 'NN'), ('attendant', 'NN'), ('wig', 'VBD'), ('stuck', 'JJ'), ('court', 'NN'), ('chancery', 'NN'), (',', ','), ('decaying', 'VBG'), ('house', 'NN'), ('blighted', 'VBD'), ('every', 'DT'), ('worn-out', 'NN'), ('lunatic', 'JJ'), ('every', 'DT'), ('dead', 'JJ'), ('every', 'DT'), ('churchyard', 'NN'), (',', ','), ('ruined', 'VBD'), ('suitor', 'NN'), ('heel', 'NN'), ('threadbare', 'NN'), ('dress', 'NN'), ('borrowing', 'VBG'), ('begging', 'VBG'), ('round', 'NN'), ('every', 'DT'), ('man', 'NN'), ("'s", 'POS'), ('acquaintance', 'NN'), (',', ','), ('give', 'VB'), ('might', 'MD'), ('mean', 'VB'), ('abundantly', 'RB'), ('right', 'RB'), (',', ','), ('patience', 'NN'), (',', ','), ('courage', 'NN'), (',', ','), ('hope', 'NN'), (',', ','), ('brain', 'NN'), ('break', 'JJ'), ('heart', 'NN'), (',', ','), ('honourable', 'JJ'), ('man', 'NN'), ('among', 'IN'), ('practitioner', 'NN'), ('would', 'MD'), ('often', 'RB'), ('warning', 'VBG'), (',', ','), ('wrong', 'JJ'), ('done', 'VBN'), ('rather', 'RB'), ('come',  ...
#  Tree('S', [('happen', 'VB'), ('lord', 'NN'), ('chancellor', 'NN'), ("'s", 'POS'), ('court', 'NN'), ('murky', 'VBD'), ('afternoon', 'NN'), ('besides', 'IN'), ('lord', 'NN'), ('chancellor', 'NN'), (',', ','), ('counsel', 'NN'), ('cause', 'NN'), (',', ','), ('two', 'CD'), ('three', 'CD'), ('counsel', 'NN'), ('never', 'RB'), ('cause', 'NN'), (',', ','), ('well', 'RB'), ('solicitor', 'NN'), ('registrar', 'NN'), ('judge', 'NN'), (',', ','), ('wig', 'VBD'), ('two', 'CD'), ('three', 'CD'), ('maces', 'NNS'), (',', ','), ('whatever', 'WDT'), ('may', 'MD'), ('be', 'VB'), (',', ','), ('legal', 'JJ'), ('court', 'NN'), ('amusement', 'NN'), ('ever', 'RB'), ('fall', 'VB'), ('jarndyce', 'NN'), ('jarndyce', 'NN'), ('(', '('), ('the', 'DT'), ('cause', 'NN'), ('hand', 'NN'), (')', ')'), (',', ','), ('squeezed', 'VBN'), ('dry', 'JJ'), ('year', 'NN'), ('upon', 'IN'), ('year', 'NN'), ('ago', 'RB'), ('.', '.'), ('writers', 'NNS'), (',', ','), ('reporter', 'NN'), ('court', 'NN'), (',', ','), ('reporter', 'NN'), ('newspaper', 'NN'), ('invariably', 'RB'), ('rest', 'VB'), ('jarndyce', 'NN'), ('jarndyce', 'NN'), ('come', 'VBN'), ('on', 'IN'), ('.', '.'), ('place', 'NN'), ('blank', 'NN'), ('.', '.'), ('standing', 'VBG'), ('seat', 'JJ'), ('side', 'NN'), ('hall', 'NN'), (',', ','), ('better', 'JJR'), ('little', 'JJ'), ('mad', 'JJ'), ('old', 'JJ'), ('woman', 'NN'), ('squeezed', 'VBD'), ('bonnet', 'NN'), ('always', 'RB'), ('court', 'NN'), (',', ','), ('sitting', 'VBG'), ('rising', 'VBG'), (',', ','), ('always', 'RB'), ('expecting', 'VBG'), ('incomprehensible', 'JJ'), ('judgment', 'NN'), ('given', 'VBN'), ('favour', 'NNS'), ('.', '.'), ('say', 'VBP'), ('really', 'RB'), ('is', 'VBZ'), (',', ','), ('was', 'VBD'), (',', ','), ('party', 'NN'), ('suit', 'NN'), (',', ','), ('one', 'CD'), ('know', 'VBP'), ('certain', 'JJ'), ('one', 'CD'), ('carry', 'NN'), ('small', 'JJ'), ('litter', 'NN'), ('reticule', 'NN'), ('call', 'NN'), ('documents', 'NNS'), (',', ','), ('principally', 'RB'), ('consisting', 'VBG'), ('paper', 'NN'), ('dry', 'JJ'), ('lavender', 'NN'), ('.', '.'), ('sallow', 'JJ'), ('prisoner', 'NN'), ('come', 'VB'), ('up', 'RP'), (',', ','), ('custody', 'NN'), (',', ','), ('time', 'NN'), ('make', 'VBP'), ('personal', 'JJ'), ('application', 'NN'), ('``', '``'), ('to', 'TO'), ('which', 'WDT'), (',', ','), ('solitary', 'JJ'), ('fallen', 'VBN'), ('state', 'NN'), ('conglomeration', 'NN'), ('account', 'NN'), ('pretended', 'VBD'), ('ever', 'RB'), ('knowledge', 'NN'), (',', ','), ('likely', 'RB'), ('ever', 'RB'), ('do', 'VBP'), ('.', '.'), ('meantime', 'VB'), ('prospect', 'JJ'), ('life', 'NN'), ('another', 'DT'), ('ruined', 'VBN'), ('suitor', 'NN'), (',', ','), ('periodically', 'RB'), ('appears', 'VBZ'), ('shropshire', 'JJ'), ('break', 'NN'), ('effort', 'NN'), ('address', 'NN'), ('chancellor', 'NN'), ('close', 'JJ'), ('day', 'NN'), ("'s", 'POS'), ('business', 'NN'), ('mean', 'NN'), ('made', 'VBD'), ('understand', 'JJ'), ('chancellor', 'NN'), ('existence', 'NN'), ('making', 'VBG'), ('desolate', 'JJ'), ('quarter', 'NN'), ('century', 'NN'), (',', ','), ('plant', 'NN'), ('good', 'JJ'), ('place', 'NN'), ('keep', 'VB'), ('eye', 'NN'), ('judge', 'NN'), (',', ','), ('ready', 'JJ'), ('call', 'NN'), ('``', '``'), ('my', 'PRP$'), ('lord', 'NN'), ('!', '.'), ("''", "''"), ('voice', 'NN'), ('sonorous', 'JJ'), ('complaint', 'NN'), ('instant', 'NN'), ('lawyers', 'NNS'), ("'", 'POS'), ('clerk', 'NN'), ('others', 'NNS'), ('know', 'VBP'), ('suitor', 'NN'), ('sight', 'NN'), ('linger', 'NN'), ('chance', 'NN'), ('furnishing', 'VBG'), ('fun', 'NN'), ('dismal', 'JJ'), ('weather', 'NN'), ('little', 'JJ'), ('.', '.')]),
#  Tree('S', [('jarndyce', 'NN'), ('jarndyce', 'NN'), ('on', 'IN'), ('.', '.'), ('scarecrow', 'NN'), ('suit', 'NN'), ('has', 'VBZ'), (',', ','), ('course', 'NN'), ('time', 'NN'), (',', ','), ('become', 'VB'), ('complicated', 'JJ'), ('man', 'NN'), ('alive', 'JJ'), ('know', 'JJ'), ('means', 'VBZ'), ('.', '.'), ('party', 'NN'), ('understand', 'NN'), ('least', 'JJS'), (',', ','), ('observed', 'VBD'), ('two', 'CD'), ('chancery', 'NN'), ('lawyer', 'NN'), ('talk', 'NN'), ('five', 'CD'), ('minute', 'NN'), ('without', 'IN'), ('coming', 'VBG'), ('total', 'JJ'), ('innumerable', 'JJ'), ('child', 'NN'), ('born', 'VBN'), ('cause', 'NN'), (';', ':'), ('innumerable', 'JJ'), ('young', 'JJ'), ('people', 'NNS'), ('married', 'VBD'), ('it', 'PRP'), (';', ':'), ('innumerable', 'JJ'), ('old', 'JJ'), ('people', 'NNS'), ('died', 'VBD'), ('it', 'PRP'), ('.', '.'), ('score', 'RBR'), ('person', 'NN'), ('found', 'VBD'), ('made', 'VBN'), ('party', 'NN'), ('jarndyce', 'NN'), ('jarndyce', 'NN'), ('without', 'IN'), ('knowing', 'VBG'), ('why', 'WRB'), (';', ':'), ('whole', 'JJ'), ('family', 'NN'), ('inherited', 'VBD'), ('suit', 'NN'), ('.', '.'), ('little', 'JJ'), ('plaintiff', 'JJ'), ('defendant', 'NN'), ('promised', 'VBD'), ('new', 'JJ'), ('jarndyce', 'NN'), ('jarndyce', 'NN'), ('settled', 'VBD'), ('grown', 'VBN'), ('up', 'RP'), (',', ','), ('possessed', 'JJ'), ('real', 'JJ'), ('horse', 'NN'), (',', ','), ('trotted', 'VBN'), ('away', 'RP'), ('world', 'NN'), ('.', '.'), ('fair', 'JJ'), ('ward', 'JJ'), ('court', 'NN'), ('faded', 'VBD'), ('mother', 'RB'), ('long', 'JJ'), ('procession', 'NN'), ('chancellor', 'NN'), ('come', 'VB'), ('gone', 'VBN'), ('out', 'RP'), (';', ':'), ('legion', 'NN'), ('bill', 'NN'), ('suit', 'NN'), ('mere', 'JJ'), ('bill', 'NN'), ('three', 'CD'), ('left', 'VBD'), ('upon', 'IN'), ('earth', 'NN'), ('perhaps', 'RB'), ('since', 'IN'), ('old', 'JJ'), ('tom', 'NN'), ('jarndyce', 'NN'), ('despair', 'NN'), ('blew', 'VBD'), ('brain', 'NN'), ('chancery', 'NN'), ('jarndyce', 'NN'), ('jarndyce', 'NN'), ('still', 'RB'), ('drag', 'VBZ'), ('dreary', 'JJ'), ('length', 'NN'), ('court', 'NN'), (',', ',')]),
#  Tree('S', [('jarndyce', 'NN'), ('jarndyce', 'NN'), ('passed', 'VBD'), ('good', 'JJ'), ('ever', 'RB'), ('come', 'VBP'), ('it', 'PRP'), ('.', '.'), ('death', 'NN'), ('many', 'JJ'), (',', ','), ('joke', 'JJ'), ('profession', 'NN'), ('.', '.'), ('every', 'DT'), ('master', 'NN'), ('chancery', 'NN'), ('reference', 'NN'), ('it', 'PRP'), ('.', '.'), ('every', 'DT'), ('chancellor', 'NN'), ('``', '``'), ('in', 'IN'), ('it', 'PRP'), (',', ','), ("''", "''"), ('somebody', 'NN'), ('other', 'JJ'), (',', ','), ('counsel', 'NN'), ('bar', 'NN'), ('.', '.'), ('good', 'JJ'), ('thing', 'NN'), ('said', 'VBD'), ('old', 'JJ'), ('select', 'JJ'), ('port-wine', 'JJ'), ('committee', 'NN'), ('dinner', 'NN'), ('hall', 'NN'), ('.', '.'), ('articled', 'VBN'), ('clerk', 'NN'), ('habit', 'NN'), ('legal', 'JJ'), ('wit', 'NN'), ('upon', 'IN'), ('it', 'PRP'), ('.', '.'), ('last', 'JJ'), ('lord', 'JJ'), ('chancellor', 'NN'), ('neatly', 'RB'), (',', ','), ('when', 'WRB'), (',', ','), ('correcting', 'VBG'), ('mr.', 'JJ'), ('eminent', 'JJ'), ('silk', 'NN'), ('gown', 'VBN'), ('said', 'VBD'), ('thing', 'NN'), ('might', 'MD'), ('happen', 'VB'), ('sky', 'NN'), ('rained', 'VBD'), ('potatoes', 'NNS'), (',', ','), ('observed', 'VBD'), (',', ','), ('``', '``'), ('or', 'CC'), ('get', 'VB'), ('jarndyce', 'JJ'), ('jarndyce', 'NN'), (',', ','), ('mr.', 'FW'), ('particularly', 'RB'), ('maces', 'NNS'), (',', ','), ('bags', 'NNS'), (',', ','), ('purses', 'NNS'), ('.', '.')]),
#  Tree('S', [('many', 'JJ'), ('people', 'NNS'), ('suit', 'VBP'), ('jarndyce', 'JJ'), ('jarndyce', 'NN'), ('stretched', 'VBD'), ('forth', 'JJ'), ('unwholesome', 'JJ'), ('hand', 'NN'), ('spoil', 'NN'), ('corrupt', 'NN'), ('would', 'MD'), ('wide', 'JJ'), ('question', 'NN'), ('.', '.'), ('master', 'NN'), ('upon', 'IN'), ('whose', 'WP$'), ('dusty', 'JJ'), ('warrant', 'NN'), ('jarndyce', 'NN'), ('jarndyce', 'NN'), ('grimly', 'RB'), ('many', 'JJ'), ('shapes', 'NNS'), (',', ','), ('six', 'CD'), ('office', 'NN'), ('copied', 'VBD'), ('ten', 'CD'), ('thousand', 'CD'), ('chancery', 'NN'), ('eternal', 'JJ'), ('man', 'NN'), ("'s", 'POS'), ('nature', 'NN'), ('made', 'VBD'), ('better', 'JJR'), ('it', 'PRP'), ('.', '.'), ('false', 'JJ'), ('pretence', 'NN'), ('sorts', 'NNS'), (',', ','), ('influence', 'NN'), ('never', 'RB'), ('come', 'VBN'), ('good', 'JJ'), ('.', '.'), ('boy', 'NN'), ('kept', 'VBD'), ('wretched', 'JJ'), ('suitor', 'NN'), ('protesting', 'NN'), ('time', 'NN'), ('mind', 'IN'), ('mr.', 'JJ'), ('chizzle', 'NN'), (',', ','), ('mizzle', 'NN'), (',', ','), ('otherwise', 'RB'), ('particularly', 'RB'), ('engaged', 'VBN'), ('appointment', 'NN'), ('dinner', 'NN'), (',', ','), ('may', 'MD'), ('got', 'VB'), ('extra', 'JJ'), ('moral', 'JJ'), ('twist', 'NN'), ('shuffle', 'NN'), ('jarndyce', 'NN'), ('jarndyce', 'NN'), ('.', '.'), ('cause', 'NN'), ('acquired', 'VBD'), ('goodly', 'RB'), ('sum', 'JJ'), ('money', 'NN'), ('acquired', 'VBD'), ('distrust', 'RB'), ('mother', 'RBR'), ('contempt', 'JJ'), ('kind', 'NN'), ('.', '.'), ('chizzle', 'NN'), (',', ','), ('mizzle', 'NN'), (',', ','), ('otherwise', 'RB'), ('lapsed', 'VBN'), ('habit', 'NN'), ('vaguely', 'RB'), ('promising', 'JJ'), ('look', 'NN'), ('outstanding', 'JJ'), ('little', 'JJ'), ('matter', 'NN'), ('see', 'VB'), ('done', 'VBN'), ('well', 'RB'), ('jarndyce', 'JJ'), ('jarndyce', 'NN'), ('shall', 'MD'), ('got', 'VB'), ('office', 'NN'), ('.', '.'), ('shirking', 'VBG'), ('many', 'JJ'), ('variety', 'NN'), ('ill-fated', 'JJ'), ('cause', 'NN'), (';', ':'), ('even', 'RB'), ('contemplated', 'VBD'), ('history', 'NN'), ('circle', 'NN'), ('evil', 'NN'), ('insensibly', 'RB'), ('tempted', 'VBD'), ('loose', 'JJ'), ('way', 'NN'), ('letting', 'VBG'), ('bad', 'JJ'), ('thing', 'NN'), ('alone', 'RB'), ('take', 'VBP'), ('bad', 'JJ'), ('course', 'NN'), (',', ','), ('loose', 'JJ'), ('belief', 'NN'), ('world', 'NN'), ('go', 'VBP'), ('wrong', 'JJ'), ('off-hand', 'JJ'), ('manner', 'NN'), ('never', 'RB'), ('meant', 'VBD'), ('go', 'VB'), ('right', 'RB'), ('.', '.')]),
#  Tree('S', [('thus', 'RB'), (',', ','), ('midst', 'NN'), ('mud', 'JJ'), ('heart', 'NN'), ('fog', 'NN'), (',', ','), ('sits', 'VBZ'), ('lord', 'RB'), ('high', 'JJ'), ('chancellor', 'NN'), ('high', 'JJ'), ('court', 'NN'), ('chancery', 'NN'), ('.', '.')]),
#  Tree('S', [('``', '``'), ('mr.', 'NNS'), ('say', 'VBP'), ('lord', 'JJ'), ('high', 'JJ'), ('chancellor', 'NN'), (',', ','), ('something', 'NN'), ('restless', 'JJ'), ('eloquence', 'NN'), ('learned', 'VBD'), ('gentleman', 'NN'), ('.', '.')]),
#  Tree('S', [('``', '``'), ('mlud', 'NN'), (',', ','), ("''", "''"), ('say', 'VBP'), ('mr.', 'IN'), Tree('PERSON', [('mr.', 'NNP')]), ('tangle', 'NNP'), ('know', 'VBP'), ('jarndyce', 'NN'), ('jarndyce', 'NN'), ('anybody', 'NN'), ('.', '.'), ('famous', 'JJ'), ('never', 'RB'), ('read', 'VBP'), ('anything', 'NN'), ('else', 'RB'), ('since', 'IN'), ('left', 'VBN'), ('school', 'NN'), ('.', '.')]),
#  Tree('S', [('``', '``'), ('have', 'VBP'), ('nearly', 'RB'), ('concluded', 'VBN'), ('argument', 'NN'), ('?', '.'), ("''", "''")]),
#  Tree('S', [('``', '``'), ('mlud', 'NN'), (',', ','), ('duty', 'NN'), ('reply', 'NN'), ('mr', 'NN'), ('.', '.')]),
#  Tree('S', [('``', '``'), ('several', 'JJ'), ('member', 'NN'), ('bar', 'NN'), ('still', 'RB'), ('heard', 'VBN'), (',', ','), ('believe', 'VB'), ('?', '.'), ("''", "''"), ('say', 'VBP'), ('chancellor', 'NN'), ('slight', 'JJ'), ('smile', 'NN'), ('.', '.')]),
#  Tree('S', [('eighteen', 'JJ'), ('mr.', 'NN'), ('learned', 'VBD'), ('friends', 'NNS'), (',', ','), ('little', 'JJ'), ('eighteen', 'JJ'), ('hundred', 'VBD'), ('bob', 'NNS'), ('like', 'IN'), ('eighteen', 'JJ'), ('make', 'VBP'), ('eighteen', 'JJ'), ('bows', 'NNS'), (',', ','), ('drop', 'NN'), ('eighteen', 'JJ'), ('place', 'NN'), ('obscurity', 'NN'), ('.', '.')]),
#  Tree('S', [('``', '``'), ('we', 'PRP'), ('proceed', 'VBP'), ('hearing', 'VBG'), ('wednesday', 'NNS'), ('say', 'VBP'), ('chancellor', 'NN'), ('.', '.'), ('question', 'NN'), ('issue', 'NN'), ('question', 'NN'), ('costs', 'NNS'), (',', ','), ('mere', 'JJ'), ('forest', 'JJS'), ('tree', 'JJ'), ('parent', 'NN'), ('suit', 'NN'), (',', ','), ('really', 'RB'), ('come', 'VBN'), ('settlement', 'NN'), ('one', 'CD'), ('days', 'NNS'), ('.', '.')]),
#  Tree('S', [('chancellor', 'NN'), ('rises', 'VBZ'), (';', ':'), ('bar', 'NN'), ('rises', 'VBZ'), (';', ':'), ('prisoner', 'NN'), ('brought', 'VBD'), ('forward', 'RB'), ('man', 'NN'), ('shropshire', 'NN'), ('cries', 'NNS'), (',', ','), ('``', '``'), ('my', 'PRP$'), ('lord', 'NN'), ('!', '.'), ("''", "''"), ('maces', 'NNS'), (',', ','), ('bags', 'NNS'), (',', ','), ('purse', 'NN'), ('indignantly', 'RB'), ('proclaim', 'JJ'), ('silence', 'NN'), ('frown', 'JJ'), ('man', 'NN')]),
#  Tree('S', [('``', '``'), ('in', 'IN'), ('reference', 'NN'), (',', ','), ("''", "''"), ('proceeds', 'VBZ'), ('chancellor', 'NN'), (',', ','), ('still', 'RB'), ('jarndyce', 'JJ'), ('jarndyce', 'NN'), (',', ','), ('``', '``'), ('to', 'TO'), ('young', 'JJ'), ('girl—', 'NN'), ("''", "''")]),
#  Tree('S', [('say', 'VB'), ('mr.', 'NN'), ('tangle', 'NN'), ('``', '``'), ('in', 'IN'), ('reference', 'NN'), (',', ','), ("''", "''"), ('proceeds', 'VBZ'), ('chancellor', 'NN'), ('extra', 'JJ'), ('distinctness', 'NN'), (',', ','), ('``', '``'), ('to', 'TO'), ('young', 'JJ'), ('girl', 'NN'), ('boy', 'NN'), (',', ','), ('two', 'CD'), ('young', 'JJ'), ('tangle', 'NNS'), ('directed', 'VBD'), ('attendance', 'RB'), ('to-day', 'JJ'), ('private', 'JJ'), ('room', 'NN'), (',', ','), ('see', 'VBP'), ('satisfy', 'JJ'), ('expediency', 'NN'), ('making', 'VBG'), ('order', 'NN'), ('residing', 'VBG'), ('uncle', 'NN'), ('.', '.'), ("''", "''")]),
#  Tree('S', [Tree('PERSON', [('mr.', 'NN')]), ('tangle', 'NNP'), ('leg', 'VBZ'), ('again', 'RB'), ('.', '.'), ('pardon—dead', 'NN'), ('.', '.'), ("''", "''")]),
#  Tree('S', [('``', '``'), ('with', 'IN'), ('looking', 'VBG'), ('double', 'JJ'), ('eye-glass', 'JJ'), ('paper', 'NN'), ('desk—', 'NN'), ("''", "''"), ('grandfather', 'NN'), ('.', '.'), ("''", "''")]),
#  Tree('S', [('rash', 'NN'), ('action—brains', 'NNS'), ('.', '.'), ("''", "''")]),
#  Tree('S', [('suddenly', 'RB'), ('little', 'JJ'), ('counsel', 'NN'), ('terrific', 'JJ'), ('bass', 'NN'), ('voice', 'NN'), ('arises', 'NNS'), (',', ','), ('fully', 'RB'), ('back', 'RB'), ('settlement', 'NN'), ('fog', 'NN'), (',', ','), ('says', 'VBZ'), (',', ','), ('``', '``'), ('will', 'MD'), ('lordship', 'VB'), ('allow', 'VB'), ('me', 'PRP'), ('?', '.'), ('appear', 'VBP'), ('him', 'PRP'), ('.', '.'), ('cousin', 'NN'), (',', ','), ('several', 'JJ'), ('time', 'NN'), ('removed', 'VBN'), ('.', '.'), ('moment', 'NN'), ('prepared', 'JJ'), ('inform', 'NN'), ('court', 'NN'), ('exact', 'JJ'), ('remove', 'VB'), ('cousin', 'NN'), (',', ','), ('cousin', 'NN'), ('.', '.'), ("''", "''")]),
#  Tree('S', [('leaving', 'VBG'), ('address', 'NN'), ('like', 'IN'), ('ringing', 'VBG'), ('rafter', 'NN'), ('roof', 'NN'), (',', ','), ('little', 'JJ'), ('counsel', 'NN'), ('drops', 'NNS'), (',', ','), ('fog', 'NN'), ('know', 'VBD'), ('more', 'RBR'), ('.', '.'), ('everybody', 'NN'), ('look', 'VBD'), ('him', 'PRP'), ('.', '.'), ('nobody', 'NN'), ('see', 'VBD'), ('him', 'PRP'), ('.', '.')]),
#  Tree('S', [('``', '``'), ('i', 'NN'), ('speak', 'JJ'), ('young', 'JJ'), ('people', 'NNS'), (',', ','), ("''", "''"), ('say', 'VBP'), ('chancellor', 'NN'), ('``', '``'), ('and', 'CC'), ('satisfy', 'VB'), ('subject', 'JJ'), ('residing', 'VBG'), ('cousin', 'NN'), ('.', '.'), ('mention', 'NN'), ('matter', 'NN'), ('to-morrow', 'JJ'), ('morning', 'NN'), ('take', 'VB'), ('seat', 'NN'), ('.', '.'), ("''", "''")]),
#  Tree('S', [('chancellor', 'NN'), ('bow', 'NN'), ('bar', 'NN'), ('prisoner', 'NN'), ('presented', 'VBN'), ('.', '.'), ('nothing', 'NN'), ('possibly', 'RB'), ('come', 'VBN'), ('conglomeration', 'NN'), ('sent', 'VBN'), ('back', 'RB'), ('prison', 'NN'), (',', ','), ('soon', 'RB'), ('done', 'VBN'), ('.', '.'), ('man', 'NN'), ('shropshire', 'NN'), ('venture', 'NN'), ('another', 'DT'), ('``', '``'), ('my', 'PRP$'), ('lord', 'NN'), ('!', '.'), ("''", "''"), ('chancellor', 'NN'), (',', ','), ('aware', 'JJ'), ('him', 'PRP'), (',', ','), ('everybody', 'NN'), ('else', 'RB'), ('quickly', 'RB'), ('vanishes', 'NNS'), ('too', 'RB'), ('.', '.'), ('battery', 'NN'), ('blue', 'JJ'), ('bag', 'NN'), ('loaded', 'VBD'), ('heavy', 'JJ'), ('charge', 'NN'), ('paper', 'NN'), ('carried', 'VBD'), ('little', 'JJ'), ('mad', 'JJ'), ('old', 'JJ'), ('woman', 'NN'), ('march', 'NN'), ('empty', 'JJ'), ('court', 'NN'), ('locked', 'VBD'), ('up', 'RP'), ('.', '.'), ('injustice', 'NN'), ('committed', 'VBD'), ('misery', 'NN'), ('caused', 'VBN'), ('could', 'MD'), ('locked', 'VB'), ('it', 'PRP'), (',', ','), ('whole', 'JJ'), ('burnt', 'NN'), ('away', 'RB'), ('great', 'JJ'), ('funeral', 'JJ'), ('much', 'RB'), ('better', 'RBR'), ('party', 'NN'), ('party', 'NN'), ('jarndyce', 'NN'), ('jarndyce', 'NN'), ('!', '.')]),
#  Tree('S', [('glimpse', 'NN'), ('world', 'NN'), ('fashion', 'NN'), ('want', 'VBP'), ('miry', 'NN'), ('afternoon', 'NN'), ('.', '.'), ('unlike', 'IN'), ('court', 'NN'), ('chancery', 'NN'), ('may', 'MD'), ('pas', 'VB'), ('one', 'CD'), ('scene', 'NN'), ('other', 'JJ'), (',', ','), ('crow', 'JJ'), ('flies', 'NNS'), ('.', '.'), ('world', 'NN'), ('fashion', 'NN'), ('court', 'NN'), ('chancery', 'JJ'), ('thing', 'NN'), ('rip', 'NN'), ('played', 'VBD'), ('strange', 'JJ'), ('game', 'NN'), ('deal', 'NN'), ('weather', 'NN'), (';', ':'), ('sleeping', 'VBG'), ('beauty', 'NN'), ('wake', 'VBP'), ('one', 'CD'), ('day', 'NN'), (',', ','), ('stopped', 'VBD'), ('spit', 'NN'), ('kitchen', 'VB'), ('shall', 'MD'), ('begin', 'VB'), ('turn', 'VB'), ('prodigiously', 'RB'), ('!', '.')]),
#  Tree('S', [('large', 'JJ'), ('world', 'NN'), ('.', '.'), ('even', 'RB'), ('world', 'NN'), ('ours', 'NN'), (',', ','), ('limit', 'NN'), ('(', '('), ('as', 'IN'), ('highness', 'NN'), ('shall', 'MD'), ('find', 'VB'), ('made', 'VBN'), ('tour', 'JJ'), ('come', 'JJ'), ('brink', 'NN'), ('void', 'JJ'), ('little', 'RB'), ('much', 'RB'), ('good', 'JJ'), ('it', 'PRP'), (';', ':'), ('many', 'JJ'), ('good', 'JJ'), ('true', 'JJ'), ('people', 'NNS'), ('it', 'PRP'), (';', ':'), ('appointed', 'VBN'), ('place', 'NN'), ('.', '.'), ('evil', 'JJ'), ('world', 'NN'), ('wrapped', 'VBD'), ('much', 'JJ'), ('cotton', 'NN'), ('fine', 'NN'), ('can', 'MD'), ('not', 'RB'), ('hear', 'VB'), ('rushing', 'VBG'), ('larger', 'JJR'), ('can', 'MD'), ('not', 'RB'), ('see', 'VB'), ('circle', 'NN'), ('round', 'NN'), ('sun', 'NN'), ('.', '.'), ('world', 'NN'), (',', ','), ('growth', 'NN'), ('sometimes', 'RB'), ('unhealthy', 'JJ'), ('want', 'VBP'), ('air', 'NN'), ('.', '.')]),
#  Tree('S', [('lady', 'NN'), ('dedlock', 'NN'), ('returned', 'VBN'), ('house', 'NN'), ('town', 'NN'), ('day', 'NN'), ('previous', 'JJ'), ('departure', 'NN'), ('paris', 'NN'), (',', ','), ('ladyship', 'JJ'), ('intends', 'VBZ'), ('stay', 'JJ'), ('weeks', 'NNS'), (',', ','), ('movement', 'NN'), ('uncertain', 'NN'), ('.', '.'), ('fashionable', 'JJ'), ('intelligence', 'NN'), ('say', 'VBP'), ('comfort', 'NN'), ('know', 'VBP'), ('fashionable', 'JJ'), ('things', 'NNS'), ('.', '.'), ('know', 'VB'), ('thing', 'NN'), ('otherwise', 'RB'), ('lady', 'JJ'), ('dedlock', 'NN'), ('calls', 'NNS'), (',', ','), ('familiar', 'JJ'), ('conversation', 'NN'), (',', ','), ('lincolnshire', 'NN'), ('.', '.'), ('water', 'NN'), ('lincolnshire', 'NN'), ('.', '.'), ('arch', 'NN'), ('bridge', 'NN'), ('park', 'NN'), ('away', 'RB'), ('.', '.'), ('adjacent', 'JJ'), ('low-lying', 'JJ'), ('ground', 'NN'), ('half', 'NN'), ('mile', 'JJ'), ('breadth', 'NN'), ('stagnant', 'NN'), ('river', 'NN'), ('melancholy', 'NN'), ('tree', 'JJ'), ('surface', 'NN'), ('over', 'IN'), (',', ','), ('day', 'NN'), ('long', 'RB'), (',', ','), ('falling', 'VBG'), ('rain', 'NN'), ('.', '.'), ('lady', 'JJ'), ('dedlock', 'NN'), ("'s", 'POS'), ('place', 'NN'), ('extremely', 'RB'), ('dreary', 'JJ'), ('.', '.'), ('weather', 'CC'), ('many', 'JJ'), ('day', 'NN'), ('night', 'NN'), ('wet', 'NN'), ('tree', 'NN'), ('seem', 'VBP'), ('wet', 'VBN'), ('through', 'IN'), (',', ','), ('soft', 'JJ'), ('make', 'VBP'), ('crash', 'JJ'), ('fall', 'NN'), ('.', '.'), ('deer', 'NN'), (',', ','), ('looking', 'VBG'), ('leave', 'JJ'), ('pass', 'NN'), ('.', '.'), ('shot', 'NN'), ('rifle', 'NN'), ('loses', 'VBZ'), ('sharpness', 'JJ'), ('moist', 'NN'), ('air', 'NN'), (',', ','), ('smoke', 'VBD'), ('move', 'NN'), ('tardy', 'NN'), ('little', 'JJ'), ('cloud', 'JJ'), ('towards', 'NNS'), ('green', 'JJ'), ('rise', 'NN'), (',', ','), ('make', 'VBP'), ('background', 'NN'), ('falling', 'VBG'), ('rain', 'NN'), ('.', '.'), ('view', 'NN'), ('lady', 'JJ'), ('dedlock', 'NN'), ("'s", 'POS'), ('window', 'JJ'), ('view', 'NN'), ('view', 'NN'), ('indian', 'JJ'), ('ink', 'NN'), ('.', '.'), ('stone', 'NN'), ('terrace', 'NN'), ('foreground', 'NN'), ('catch', 'NN'), ('rain', 'NN'), ('heavy', 'JJ'), ('drop', 'NN'), ('drip', 'NN'), (',', ','), ('broad', 'JJ'), ('flagged', 'VBD'), ('pavement', 'NN'), (',', ','), ('called', 'VBN'), ('old', 'JJ'), ('time', 'NN'), ('ghost', 'NN'), ("'s", 'POS'), ('walk', 'NN'), (',', ','), ('night', 'NN'), ('.', '.'), ('little', 'JJ'), ('church', 'NN'), ('park', 'NN'), ('pulpit', 'NN'), ('break', 'NN'), ('cold', 'JJ'), ('general', 'JJ'), ('smell', 'NN'), ('taste', 'NN'), ('ancient', 'NN'), ('dedlocks', 'NNS'), ('lady', 'JJ'), ('dedlock', 'NN'), ('(', '('), ('who', 'WP'), ('looking', 'VBG'), ('early', 'JJ'), ('twilight', 'NN'), ('keeper', 'NN'), ("'s", 'POS'), ('lodge', 'NN'), ('seeing', 'VBG'), ('light', 'JJ'), ('fire', 'NN'), ('upon', 'IN'), ('smoke', 'NN'), ('rising', 'VBG'), ('chimney', 'NN'), (',', ','), ('child', 'NN'), (',', ','), ('woman', 'NN'), (',', ','), ('running', 'VBG'), ('rain', 'NN'), ('meet', 'NN'), ('shining', 'JJ'), ('figure', 'NN'), ('man', 'NN'), ('coming', 'VBG'), ('gate', 'NN'), (',', ','), ('put', 'VBD'), ('quite', 'RB'), ('temper', 'JJ'), ('.', '.'), ('lady', 'JJ'), ('dedlock', 'NNS'), ('say', 'VBP'), ('death', 'NN'), ('.', '.'), ("''", "''")]),
#  Tree('S', [('therefore', 'RB'), ('lady', 'JJ'), ('dedlock', 'NN'), ('come', 'VB'), ('away', 'RB'), ('place', 'NN'), ('lincolnshire', 'NN'), ('left', 'VBD'), ('rain', 'NN'), (',', ','), ('deer', 'NN'), (',', ','), ('picture', 'NN'), ('dedlocks', 'NNS'), ('past', 'IN'), ('gone', 'VBN'), ('seemed', 'VBD'), ('vanish', 'JJ'), ('damp', 'NN'), ('wall', 'NN'), ('mere', 'JJ'), ('lowness', 'JJ'), ('spirits', 'NNS'), (',', ','), ('housekeeper', 'NN'), ('passed', 'VBD'), ('along', 'IN'), ('old', 'JJ'), ('room', 'NN'), ('shutting', 'VBG'), ('next', 'JJ'), ('come', 'JJ'), ('forth', 'NN'), ('again', 'RB'), (',', ','), ('fashionable', 'JJ'), ('like', 'IN'), ('past', 'JJ'), ('present', 'NN'), (',', ','), ('yet', 'RB'), ('undertake', 'JJ'), ('say', 'NN'), ('.', '.')]),
#  Tree('S', [('sir', 'NN'), ('leicester', 'NN'), ('dedlock', 'NN'), ('baronet', 'NN'), (',', ','), ('baronet', 'NN'), ('he', 'PRP'), ('.', '.'), ('family', 'NN'), ('old', 'JJ'), ('hills', 'NNS'), (',', ','), ('infinitely', 'RB'), ('respectable', 'JJ'), ('.', '.'), ('general', 'JJ'), ('opinion', 'NN'), ('world', 'NN'), ('might', 'MD'), ('get', 'VB'), ('without', 'IN'), ('would', 'MD'), ('done', 'VBN'), ('without', 'IN'), ('would', 'MD'), ('whole', 'VB'), ('admit', 'JJ'), ('nature', 'NN'), ('good', 'JJ'), ('idea', 'NN'), ('(', '('), ('a', 'DT'), ('little', 'RB'), ('low', 'JJ'), (',', ','), ('perhaps', 'RB'), (',', ','), ('enclosed', 'VBD'), ('idea', 'NN'), ('dependent', 'NN'), ('great', 'JJ'), ('county', 'NN'), ('families', 'NNS'), ('.', '.'), ('gentleman', 'JJ'), ('strict', 'JJ'), ('disdainful', 'NN'), ('meanness', 'NN'), ('ready', 'JJ'), ('shortest', 'JJ'), ('notice', 'NN'), ('die', 'NNS'), ('death', 'NN'), ('may', 'MD'), ('please', 'VB'), ('mention', 'NN'), ('rather', 'RB'), ('give', 'JJ'), ('occasion', 'NN'), ('least', 'JJS'), ('impeachment', 'JJ'), ('honourable', 'JJ'), (',', ','), ('intensely', 'RB'), ('perfectly', 'RB'), ('unreasonable', 'JJ'), ('man', 'NN'), ('.', '.')]),
#  Tree('S', [('sir', 'NN'), ('leicester', 'RBR'), ('twenty', 'CD'), ('years', 'NNS'), (',', ','), ('full', 'JJ'), ('older', 'JJR'), ('lady', 'NN'), ('.', '.'), ('never', 'RB'), ('see', 'VB'), ('again', 'RB'), (',', ','), ('perhaps', 'RB'), ('yet', 'RB'), ('twist', 'JJ'), ('gout', 'NN'), ('walk', 'NN'), ('little', 'JJ'), ('worthy', 'JJ'), ('presence', 'NN'), (',', ','), ('hair', 'NN'), ('whiskers', 'NNS'), (',', ','), ('fine', 'JJ'), ('shirt-frill', 'NN'), (',', ','), ('waistcoat', 'NN'), (',', ','), ('blue', 'JJ'), ('coat', 'NN'), ('bright', 'VBD'), ('button', 'NN'), ('always', 'RB'), ('ceremonious', 'JJ'), (',', ','), ('stately', 'RB'), (',', ','), ('polite', 'JJ'), ('every', 'DT'), ('occasion', 'NN'), ('lady', 'NN'), (',', ','), ('hold', 'VBP'), ('personal', 'JJ'), ('highest', 'JJS'), ('estimation', 'NN'), ('.', '.'), ('gallantry', 'NN'), ('lady', 'NN'), (',', ','), ('never', 'RB'), ('changed', 'VBN'), ('since', 'IN'), ('courted', 'VBN'), ('her', 'PRP'), (',', ','), ('one', 'CD'), ('little', 'JJ'), ('touch', 'JJ'), ('romantic', 'JJ'), ('fancy', 'NN'), ('him', 'PRP'), ('.', '.')]),
#  Tree('S', [('indeed', 'RB'), (',', ','), ('married', 'VBD'), ('love', 'NN'), ('.', '.'), ('whisper', 'NN'), ('still', 'RB'), ('go', 'VB'), ('even', 'RB'), ('family', 'NN'), (';', ':'), ('howbeit', 'NN'), (',', ','), ('sir', 'VBP'), ('leicester', 'RB'), ('much', 'JJ'), ('family', 'NN'), ('perhaps', 'RB'), ('enough', 'RB'), ('could', 'MD'), ('dispense', 'VB'), ('more', 'JJR'), ('.', '.'), ('beauty', 'NN'), (',', ','), ('pride', 'NN'), (',', ','), ('insolent', 'JJ'), ('sense', 'NN'), ('enough', 'JJ'), ('portion', 'NN'), ('legion', 'NN'), ('fine', 'JJ'), ('wealth', 'NN'), ('station', 'NN'), (',', ','), ('added', 'VBD'), ('these', 'DT'), (',', ','), ('soon', 'RB'), ('floated', 'VBD'), ('year', 'NN'), ('lady', 'NN'), ('dedlock', 'NN'), ('centre', 'NN'), ('fashionable', 'JJ'), ('intelligence', 'NN'), ('top', 'NN'), ('fashionable', 'NN')]),
#  Tree('S', [('wept', 'NN'), ('conquer', 'NN'), (',', ','), ('everybody', 'NN'), ('reason', 'NN'), ('know', 'JJ'), ('time', 'NN'), (',', ','), ('matter', 'NN'), ('rather', 'RB'), ('frequently', 'RB'), ('mentioned', 'VBN'), ('.', '.'), ('lady', 'JJ'), ('dedlock', 'NN'), (',', ','), ('world', 'NN'), (',', ','), ('fell', 'VBD'), ('rather', 'RB'), ('exhausted', 'JJ'), ('composure', 'NN'), (',', ','), ('worn-out', 'JJ'), ('fatigue', 'NN'), ('ruffled', 'VBD'), ('interest', 'NN'), ('satisfaction', 'NN'), (',', ','), ('perfectly', 'RB'), ('could', 'MD'), ('translated', 'VB'), ('heaven', 'RB'), ('to-morrow', 'NN'), (',', ','), ('might', 'MD'), ('expected', 'VBN'), ('without', 'IN'), ('rapture', 'NN'), ('.', '.')]),
#  Tree('S', [('beauty', 'NN'), ('still', 'RB'), (',', ','), ('yet', 'RB'), ('fine', 'JJ'), ('character', 'NN'), ('would', 'MD'), ('rather', 'RB'), ('called', 'VB'), ('pretty', 'RB'), ('handsome', 'JJ'), (',', ','), ('improved', 'VBN'), ('acquired', 'VBD'), ('expression', 'NN'), ('fashionable', 'JJ'), ('state', 'NN'), ('.', '.'), ('figure', 'NN'), ('elegant', 'JJ'), ('effect', 'NN'), ('so', 'RB'), (',', ','), ('``', '``'), ('the', 'DT'), ('honourable', 'JJ'), ('bob', 'NN'), ('stable', 'JJ'), ('frequently', 'RB'), ('asserted', 'VBN'), ('upon', 'IN'), ('oath', 'NN'), (',', ','), ('``', '``'), ('of', 'IN'), ('authority', 'NN'), ('observes', 'VBZ'), ('perfectly', 'RB'), ('got', 'VBN'), ('remark', 'JJ'), ('hair', 'NN'), ('especially', 'RB'), ('best-groomed', 'JJ'), ('woman', 'NN'), ('whole', 'JJ'), ('stud', 'NN'), ('.', '.')]),
#  Tree('S', [('perfection', 'NN'), ('head', 'NN'), (',', ','), ('lady', 'JJ'), ('dedlock', 'NN'), ('come', 'VB'), ('place', 'NN'), ('lincolnshire', 'NN'), ('pursued', 'VBN'), ('fashionable', 'JJ'), ('pas', 'JJ'), ('day', 'NN'), ('house', 'NN'), ('town', 'NN'), ('previous', 'JJ'), ('departure', 'NN'), ('paris', 'NN'), (',', ','), ('ladyship', 'JJ'), ('intends', 'VBZ'), ('stay', 'JJ'), ('weeks', 'NNS'), (',', ','), ('movement', 'NN'), ('uncertain', 'NN'), ('.', '.'), ('house', 'NN'), ('town', 'NN'), (',', ','), ('upon', 'IN'), ('muddy', 'NN'), (',', ','), ('murky', 'JJ'), ('afternoon', 'NN'), (',', ','), ('present', 'JJ'), ('old-fashioned', 'JJ'), ('old', 'JJ'), ('gentleman', 'NN'), (',', ','), ('eke', 'JJ'), ('solicitor', 'NN'), ('high', 'JJ'), ('court', 'NN'), ('chancery', 'NN'), (',', ','), ('honour', 'NN'), ('acting', 'VBG'), ('legal', 'JJ'), ('adviser', 'NN'), ('dedlocks', 'NNS'), ('many', 'JJ'), ('box', 'JJ'), ('office', 'NN'), ('name', 'NN'), ('outside', 'IN'), ('present', 'JJ'), ('baronet', 'NN'), ('trick', 'NN'), ('constantly', 'RB'), ('whole', 'JJ'), ('across', 'IN'), ('hall', 'NN'), (',', ','), ('stairs', 'NNS'), (',', ','), ('along', 'IN'), ('passages', 'NNS'), (',', ','), ('rooms', 'NNS'), (',', ','), ('brilliant', 'JJ'), ('season', 'NN'), ('dismal', 'JJ'), ('visit', 'NN'), (',', ','), ('desert', 'JJ'), ('live', 'VBP'), ('in—the', 'JJ'), ('old', 'JJ'), ('gentleman', 'NN'), ('conducted', 'VBD'), ('mercury', 'NN'), ('powder', 'NN'), ('lady', 'NN'), ("'s", 'POS'), ('presence', 'NN'), ('.', '.')]),
#  Tree('S', [('old', 'JJ'), ('gentleman', 'NN'), ('rusty', 'JJ'), ('look', 'NN'), ('at', 'IN'), (',', ','), ('made', 'VBD'), ('good', 'JJ'), ('aristocratic', 'JJ'), ('marriage', 'NN'), ('settlement', 'NN'), ('aristocratic', 'JJ'), ('rich', 'JJ'), ('.', '.'), ('surrounded', 'VBN'), ('mysterious', 'JJ'), ('halo', 'NNS'), ('family', 'NN'), ('confidences', 'NNS'), (',', ','), ('known', 'VBN'), ('silent', 'JJ'), ('noble', 'JJ'), ('rooted', 'JJ'), ('century', 'NN'), ('retired', 'VBD'), ('among', 'IN'), ('growing', 'VBG'), ('timber', 'NN'), ('fern', 'JJ'), (',', ','), ('perhaps', 'RB'), ('hold', 'VB'), ('fewer', 'JJR'), ('noble', 'JJ'), ('secret', 'JJ'), ('walk', 'NN'), ('abroad', 'RB'), ('among', 'IN'), ('men', 'NNS'), (',', ','), ('shut', 'VBD'), ('breast', 'IN'), ('mr.', 'JJ'), ('tulkinghorn', 'NN'), ('.', '.'), ('called', 'VBN'), ('old', 'JJ'), ('phrase', 'NN'), ('generally', 'RB'), ('meaning', 'VBG'), ('school', 'NN'), ('seems', 'VBZ'), ('never', 'RB'), ('wear', 'VBP'), ('tied', 'JJ'), ('gaiter', 'NN'), ('one', 'CD'), ('peculiarity', 'NN'), ('black', 'JJ'), ('clothes', 'NNS'), ('black', 'JJ'), ('stockings', 'NNS'), (',', ','), ('silk', 'NN'), ('never', 'RB'), ('close', 'RB'), (',', ','), ('glancing', 'VBG'), ('light', 'NN'), (',', ','), ('dress', 'NN'), ('like', 'IN'), ('himself', 'PRP'), ('.', '.'), ('never', 'RB'), ('converse', 'VBP'), ('professionally', 'RB'), ('found', 'VBN'), ('sometimes', 'RB'), (',', ','), ('speechless', 'JJ'), ('quite', 'RB'), ('home', 'NN'), (',', ','), ('corner', 'RB'), ('great', 'JJ'), ('country', 'NN'), ('house', 'NN'), ('near', 'IN'), ('door', 'NN'), ('concerning', 'VBG'), ('fashionable', 'JJ'), ('intelligence', 'NN'), ('eloquent', 'NN'), (',', ','), ('everybody', 'NN'), ('know', 'VBP'), ('half', 'JJ'), ('peerage', 'JJ'), ('stop', 'NNS'), ('say', 'VBP'), ('``', '``'), ('how', 'WRB'), ('do', 'VB'), (',', ','), ('mr', 'VB'), ('.', '.'), ('tulkinghorn', 'VB'), ('?', '.'), ("''", "''"), ('receives', 'VBZ'), ('salutation', 'NN'), ('gravity', 'NN'), ('along', 'IN'), ('rest', 'NN'), ('knowledge', 'NN'), ('.', '.')]),
#  Tree('S', [('sir', 'NN'), ('leicester', 'NN'), ('dedlock', 'NN'), ('lady', 'NN'), ('happy', 'JJ'), ('see', 'VBP'), Tree('PERSON', [('mr.', 'JJ')]), ('tulkinghorn', 'NNP'), ('.', '.'), ('air', 'NN'), ('always', 'RB'), ('agreeable', 'JJ'), ('sir', 'JJ'), ('leicester', 'NN'), (';', ':'), ('receives', 'VBZ'), ('kind', 'NN'), ('like', 'IN'), Tree('PERSON', [('mr.', 'NN'), ('tulkinghorn', 'NNP')]), ("'s", 'POS'), ('dress', 'NN'), (';', ':'), ('kind', 'NN'), ('tribute', 'NN'), ('too', 'RB'), ('.', '.'), ('eminently', 'RB'), ('respectable', 'JJ'), (',', ','), ('likewise', 'RB'), (',', ','), ('general', 'JJ'), ('way', 'NN'), (',', ','), ('expresses', 'NNS'), (',', ','), ('were', 'VBD'), (',', ','), ('steward', 'JJ'), ('legal', 'JJ'), ('mysteries', 'NNS'), (',', ','), ('legal', 'JJ'), ('cellar', 'NN'), (',', ',')]),
# ...
#  Tree('S', [('``', '``'), ('this', 'DT'), ('lives', 'VBZ'), (',', ','), ('sir', 'NN'), (',', ','), ("''", "''"), ('say', 'VBP'), ('law-stationer', 'NN'), ('.', '.')]),
#  Tree('S', [('``', '``'), ('this', 'DT'), ('lives', 'VBZ'), (',', ','), ('it', 'PRP'), ('?', '.'), ("''", "''"), ('say', 'VBP'), ('lawyer', 'NN'), ('``', '``'), ('thank', 'NN'), ('you', 'PRP'), ('.', '.'), ("''", "''")]),
#  Tree('S', [('``', '``'), ('are', 'VBP'), ('going', 'VBG'), ('in', 'IN'), (',', ','), ('sir', 'NN'), ('?', '.'), ("''", "''")]),
#  Tree('S', [('``', '``'), ('no', 'DT'), (',', ','), ('thank', 'NN'), ('you', 'PRP'), (',', ','), ('no', 'DT'), (';', ':'), ('going', 'VBG'), ('field', 'NN'), ('present', 'JJ'), ('.', '.'), ('good', 'JJ'), ('evening', 'NN'), ('.', '.'), ('thank', 'NN'), ('you', 'PRP'), ('!', '.'), ("''", "''"), ('mr.', 'NN'), ('snagsby', 'VBD'), ('lift', 'JJ'), ('hat', 'WP'), ('return', 'VBP'), ('little', 'JJ'), ('woman', 'NN'), ('tea', 'NN'), ('.', '.')]),
#  Tree('S', [Tree('PERSON', [('mr.', 'NN')]), ('tulkinghorn', 'NNP'), ('go', 'VBP'), ('field', 'NN'), ('present', 'NN'), ('.', '.'), ('go', 'VB'), ('short', 'JJ'), ('way', 'NN'), (',', ','), ('turn', 'VBP'), ('back', 'RB'), (',', ','), ('come', 'VB'), ('shop', 'NN'), Tree('PERSON', [('mr.', 'NN'), ('krook', 'NNP')]), (',', ','), ('enters', 'VBZ'), ('dim', 'JJ'), ('enough', 'RB'), (',', ','), ('blot-headed', 'JJ'), ('candle', 'NN'), ('windows', 'NNS'), (',', ','), ('old', 'JJ'), ('man', 'NN'), ('cat', 'NN'), ('sitting', 'VBG'), ('back', 'RP'), ('part', 'NN'), ('fire', 'NN'), ('.', '.'), ('old', 'JJ'), ('man', 'NN'), ('rise', 'NN'), ('come', 'VBN'), ('forward', 'RB'), (',', ','), ('another', 'DT'), ('blot-headed', 'JJ'), ('candle', 'NN'), ('hand', 'NN'), ('.', '.')]),
#  Tree('S', [('``', '``'), ('pray', 'NN'), ('lodger', 'NN'), ('within', 'IN'), ('?', '.'), ("''", "''")]),
#  Tree('S', [('``', '``'), ('male', 'JJ'), ('female', 'NN'), (',', ','), ('sir', 'NN'), ('?', '.'), ("''", "''"), ('say', 'VBP'), Tree('PERSON', [('mr.', 'JJ')]), ('krook', 'NNP'), ('.', '.')]),
#  Tree('S', [('``', '``'), ('male', 'NN'), ('.', '.'), ('person', 'NN'), ('copying', 'NN'), ('.', '.'), ("''", "''")]),
#  Tree('S', [Tree('PERSON', [('mr.', 'NN')]), ('krook', 'NNP'), ('eyed', 'VBD'), ('man', 'NN'), ('know', 'VB'), ('sight', 'NN'), ('.', '.'), ('indistinct', 'JJ'), ('impression', 'NN'), ('aristocratic', 'JJ'), ('repute', 'NN'), ('.', '.')]),
#  Tree('S', [('``', '``'), ('did', 'VBD'), ('wish', 'JJ'), ('see', 'NN'), ('him', 'PRP'), (',', ','), ('sir', 'NN'), ('?', '.'), ("''", "''")]),
#  Tree('S', [('``', '``'), ('yes', 'RB'), ('.', '.'), ("''", "''")]),
#  Tree('S', [('``', '``'), ('it', 'PRP'), ("'s", 'VBZ'), ('seldom', 'JJ'), ('myself', 'PRP'), (',', ','), ("''", "''"), ('say', 'VBP'), ('mr.', 'JJ'), ('krook', 'NN'), ('``', '``'), ('shall', 'MD'), ('call', 'VB'), ('weak', 'JJ'), ('chance', 'NN'), ('he', 'PRP'), ("'d", 'MD'), ('come', 'VB'), (',', ','), ('sir', 'NN'), ('!', '.'), ("''", "''")]),
#  Tree('S', [('``', '``'), ('i', 'NN'), ("'ll", 'MD'), ('go', 'VB'), ('him', 'PRP'), (',', ','), ('then', 'RB'), (',', ','), ("''", "''"), ('say', 'VBP'), Tree('PERSON', [('mr.', 'JJ')]), ('tulkinghorn', 'NNP'), ('.', '.')]),
#  Tree('S', [('``', '``'), ('second', 'JJ'), ('floor', 'NN'), (',', ','), ('sir', 'NN'), ('.', '.'), ('take', 'VB'), ('candle', 'NN'), ('.', '.'), ('there', 'EX'), ('!', '.'), ("''", "''"), Tree('PERSON', [('mr.', 'NN'), ('krook', 'NNP')]), (',', ','), ('cat', 'NN'), ('beside', 'NN'), ('him', 'PRP'), (',', ','), ('stand', 'VBP'), ('bottom', 'JJ'), ('staircase', 'NN'), (',', ','), ('looking', 'VBG'), ('mr.', 'NN'), ('tulkinghorn', 'NN'), ('.', '.'), ('say', 'VBP'), ('mr.', 'JJ'), ('tulkinghorn', 'VBP'), ('nearly', 'RB'), ('disappeared', 'VBN'), ('.', '.'), ('lawyer', 'NN'), ('look', 'NN'), ('cat', 'NN'), ('expands', 'VBZ'), ('wicked', 'JJ'), ('mouth', 'NN'), ('snarl', 'VBD'), ('him', 'PRP'), ('.', '.')]),
#  Tree('S', [('``', '``'), ('order', 'NN'), (',', ','), ('lady', 'JJ'), ('visitors', 'NNS'), (',', ','), ('lady', 'NN'), ('!', '.'), ('know', 'NNS'), ('say', 'VBP'), ('whisper', 'IN'), ('krook', 'NN'), (',', ','), ('going', 'VBG'), ('step', 'NN'), ('two', 'CD'), ('.', '.')]),
#  Tree('S', [('``', '``'), ('what', 'WP'), ('say', 'VBP'), ('him', 'PRP'), ('?', '.'), ("''", "''")]),
#  Tree('S', [('``', '``'), ('they', 'PRP'), ('say', 'VBP'), ('sold', 'VBN'), ('enemy', 'RB'), (',', ','), ('know', 'VBP'), ('i', 'JJ'), ("'ll", 'MD'), ('tell', 'VB'), ('what', 'WP'), (',', ','), ('lodger', 'JJR'), ('gloomy', 'JJ'), ('believe', 'VBP'), ('he', 'PRP'), ("'d", 'MD'), ('soon', 'RB'), ('make', 'VB'), ('bargain', 'NN'), ('other', 'JJ'), ('.', '.'), ('put', 'VBN'), ('out', 'RP'), (',', ','), ('sir', 'NN'), ('.', '.'), ('that', 'DT'), ("'s", 'VBZ'), ('advice', 'NN'), ('!', '.'), ("''", "''")]),
#  Tree('S', [Tree('PERSON', [('mr.', 'NN')]), ('tulkinghorn', 'NNP'), ('nod', 'VBD'), ('go', 'VB'), ('way', 'NN'), ('.', '.'), ('come', 'VB'), ('dark', 'JJ'), ('door', 'JJ'), ('second', 'JJ'), ('floor', 'NN'), ('.', '.'), ('receives', 'VBZ'), ('answer', 'JJR'), (',', ','), ('open', 'JJ'), ('it', 'PRP'), (',', ','), ('accidentally', 'RB'), ('extinguishes', 'VBZ'), ('candle', 'NN'), ('so', 'RB'), ('.', '.')]),
#  Tree('S', [('air', 'NN'), ('room', 'NN'), ('almost', 'RB'), ('bad', 'JJ'), ('enough', 'RB'), ('extinguished', 'VBD'), ('not', 'RB'), ('.', '.'), ('small', 'JJ'), ('room', 'NN'), (',', ','), ('nearly', 'RB'), ('black', 'JJ'), ('dirt', 'NN'), ('.', '.'), ('rusty', 'JJ'), ('skeleton', 'NN'), ('grate', 'NN'), (',', ','), ('pinched', 'VBD'), ('middle', 'JJ'), ('poverty', 'NN'), ('it', 'PRP'), (',', ','), ('red', 'JJ'), ('fire', 'NN'), ('burn', 'NN'), ('low', 'JJ'), ('.', '.'), ('corner', 'NN'), ('chimney', 'NN'), ('stand', 'VBP'), ('deal', 'NN'), ('table', 'JJ'), ('broken', 'NN'), ('desk', 'NN'), (',', ','), ('wilderness', 'NN'), ('marked', 'VBD'), ('rain', 'JJ'), ('ink', 'NN'), ('.', '.'), ('another', 'DT'), ('corner', 'NN'), ('ragged', 'VBD'), ('old', 'JJ'), ('portmanteau', 'NN'), ('one', 'CD'), ('two', 'CD'), ('chair', 'NN'), ('serf', 'JJ'), ('cabinet', 'NN'), ('larger', 'JJR'), ('one', 'CD'), ('like', 'IN'), ('cheek', 'NN'), ('man', 'NN'), ('.', '.'), ('floor', 'NN'), ('bare', 'NN'), (',', ','), ('except', 'IN'), ('one', 'CD'), ('old', 'JJ'), ('mat', 'NN'), (',', ','), ('trodden', 'JJ'), ('lie', 'NN'), ('perishing', 'VBG'), ('upon', 'IN'), ('hearth', 'NN'), ('.', '.'), ('curtain', 'NN'), ('darkness', 'NN'), ('night', 'NN'), (',', ','), ('discoloured', 'VBD'), ('shutter', 'NN'), ('drawn', 'NN'), ('together', 'RB'), (',', ','), ('two', 'CD'), ('gaunt', 'NN'), ('hole', 'VBD'), ('them', 'PRP'), (',', ','), ('might', 'MD'), ('staring', 'VBG'), ('in—the', 'VB'), ('man', 'NN'), ('upon', 'IN'), ('bed', 'NN'), ('.', '.')]),
#  Tree('S', [('for', 'IN'), (',', ','), ('low', 'JJ'), ('bed', 'VBD'), ('opposite', 'JJ'), ('fire', 'NN'), (',', ','), ('confusion', 'NN'), ('dirty', 'NN'), ('coarse', 'NN'), ('lawyer', 'NN'), (',', ','), ('hesitating', 'VBG'), ('within', 'IN'), ('doorway', 'NN'), (',', ','), ('see', 'VBP'), ('man', 'NN'), ('.', '.'), ('lie', 'CC'), ('there', 'RB'), (',', ','), ('dressed', 'VBD'), ('shirt', 'NN'), ('trousers', 'NNS'), (',', ','), ('bare', 'JJ'), ('feet', 'NNS'), ('.', '.'), ('yellow', 'JJ'), ('look', 'NN'), ('spectral', 'JJ'), ('darkness', 'NN'), ('candle', 'NN'), ('guttered', 'VBD'), ('whole', 'JJ'), ('length', 'NN'), ('(', '('), ('still', 'RB'), ('doubled', 'VBN'), ('left', 'VBD'), ('tower', 'JJR'), ('it', 'PRP'), ('.', '.'), ('hair', 'NN'), ('whisker', 'NN'), ('ragged', 'VBD'), ('too', 'RB'), (',', ','), ('like', 'IN'), ('mist', 'NN'), ('around', 'IN'), ('him', 'PRP'), (',', ','), ('neglect', 'NN'), ('.', '.'), ('foul', 'NN'), ('filthy', 'JJ'), ('room', 'NN'), ('is', 'VBZ'), (',', ','), ('foul', 'JJ'), ('filthy', 'JJ'), ('air', 'NN'), ('is', 'VBZ'), (',', ','), ('easy', 'JJ'), ('perceive', 'JJ'), ('fume', 'NN'), ('sens', 'VBZ'), ('it', 'PRP'), (';', ':'), ('general', 'JJ'), ('odour', 'CD'), ('stale', 'NN'), ('tobacco', 'NN'), (',', ','), ('come', 'VB'), ('lawyer', 'NN'), ("'s", 'POS'), ('mouth', 'NN'), ('taste', 'NN')]),
#  Tree('S', [('``', '``'), ('hallo', 'NN'), (',', ','), ('friend', 'NN'), ('!', '.'), ("''", "''"), ('cries', 'NNS'), (',', ','), ('strike', 'NN'), ('iron', 'NN'), ('candlestick', 'NN'), ('door', 'NN'), ('.', '.')]),
#  Tree('S', [('think', 'NN'), ('awakened', 'VBD'), ('friend', 'NN'), ('.', '.'), ('lie', 'VB'), ('little', 'JJ'), ('turned', 'JJ'), ('away', 'RB'), (',', ','), ('eye', 'NN'), ('surely', 'RB'), ('open', 'JJ'), ('.', '.')]),
#  Tree('S', [('``', '``'), ('hallo', 'NN'), (',', ','), ('friend', 'NN'), ('!', '.'), ("''", "''"), ('cry', 'NN'), ('again', 'RB'), ('.', '.'), ('hallo', 'NN'), ('!', '.'), ("''", "''")]),
#  Tree('S', [('rattle', 'JJ'), ('door', 'NN'), (',', ','), ('candle', 'VB'), ('long', 'RB'), ('go', 'VB'), ('leaf', 'JJ'), ('dark', 'NN'), (',', ','), ('gaunt', 'NN'), ('eye', 'NN'), ('shutter', 'NN'), ('staring', 'VBG'), ('upon', 'IN'), ('bed', 'NN'), ('.', '.')]),
#  Tree('S', [('touch', 'JJ'), ('lawyer', 'NN'), ("'s", 'POS'), ('wrinkled', 'JJ'), ('hand', 'NN'), ('stand', 'VBP'), ('dark', 'NN'), ('room', 'NN'), (',', ','), ('make', 'VB'), ('start', 'NN'), ('say', 'VB'), (',', ','), ('``', '``'), ('what', 'WP'), ("'s", 'VBZ'), ('that', 'DT'), ('?', '.'), ("''", "''")]),
#  Tree('S', [('``', '``'), ('it', 'PRP'), ("'s", 'VBZ'), ('me', 'PRP'), (',', ','), ("''", "''"), ('return', 'VBP'), ('old', 'JJ'), ('man', 'NN'), ('house', 'NN'), (',', ','), ('whose', 'WP$'), ('breath', 'NN'), ('ear', 'NN'), ('.', '.'), ('``', '``'), ('ca', 'MD'), ("n't", 'RB'), ('wake', 'VB'), ('him', 'PRP'), ('?', '.'), ("''", "''")]),
#  Tree('S', [('``', '``'), ('no', 'DT'), ('.', '.'), ("''", "''")]),
#  Tree('S', [('``', '``'), ('what', 'WP'), ('done', 'VBN'), ('candle', 'NN'), ('?', '.'), ("''", "''")]),
#  Tree('S', [('``', '``'), ('it', 'PRP'), ("'s", 'VBZ'), ('gone', 'VBN'), ('out', 'RP'), ('.', '.'), ('is', 'VBZ'), ('.', '.'), ("''", "''")]),
#  Tree('S', [('krook', 'NNS'), ('take', 'VBP'), ('it', 'PRP'), (',', ','), ('go', 'VB'), ('fire', 'NN'), (',', ','), ('stoop', 'NN'), ('red', 'JJ'), ('try', 'NN'), ('get', 'VB'), ('light', 'JJ'), ('.', '.'), ('dying', 'VBG'), ('ash', 'JJ'), ('light', 'NN'), ('spare', 'NN'), (',', ','), ('endeavour', 'VBP'), ('vain', 'NN'), ('.', '.'), ('muttering', 'NN'), (',', ','), ('ineffectual', 'JJ'), ('call', 'NN'), ('lodger', 'NN'), (',', ','), ('go', 'VB'), ('downstairs', 'RB'), ('bring', 'NN'), ('lighted', 'VBD'), ('candle', 'JJ'), ('shop', 'NN'), (',', ','), ('old', 'JJ'), ('man', 'NN'), Tree('PERSON', [('mr.', 'NN'), ('tulkinghorn', 'NNP')]), (',', ','), ('new', 'JJ'), ('reason', 'NN'), ('has', 'VBZ'), (',', ','), ('await', 'VBP'), ('return', 'NN'), ('room', 'NN'), (',', ','), ('stair', 'NN'), ('outside', 'IN'), ('.', '.')]),
#  Tree('S', [('welcome', 'JJ'), ('light', 'NN'), ('soon', 'RB'), ('shine', 'JJ'), ('upon', 'IN'), ('wall', 'NN'), (',', ','), ('krook', 'VB'), ('come', 'VBP'), ('slowly', 'RB'), ('cat', 'JJ'), ('following', 'VBG'), ('heels', 'NNS'), ('.', '.'), ('``', '``'), ('does', 'VBZ'), ('man', 'NN'), ('generally', 'RB'), ('sleep', 'VBP'), ('like', 'IN'), ('this', 'DT'), ('?', '.'), ("''", "''"), ('inquired', 'VBD'), ('lawyer', 'NN'), ('low', 'JJ'), ('voice', 'NN'), ('.', '.'), ('``', '``'), ('hi', 'JJ'), ('!', '.'), ('know', 'NN'), (',', ','), ("''", "''"), ('say', 'VBP'), ('krook', 'NN'), (',', ','), ('shaking', 'VBG'), ('head', 'NN'), ('lifting', 'VBG'), ('eyebrows', 'NNS'), ('.', '.'), ('``', '``'), ('i', 'NN'), ('know', 'VBP'), ('next', 'IN'), ('nothing', 'NN'), ('habit', 'NN'), ('except', 'IN'), ('keep', 'JJ'), ('close', 'NN'), ('.', '.'), ("''", "''")]),
#  Tree('S', [('thus', 'RB'), ('whispering', 'NN'), (',', ','), ('go', 'VB'), ('together', 'RB'), ('.', '.'), ('light', 'JJ'), ('go', 'NN'), ('in', 'IN'), (',', ','), ('great', 'JJ'), ('eye', 'NN'), ('shutters', 'NNS'), (',', ','), ('seem', 'VBP'), ('close', 'RB'), ('.', '.'), ('eye', 'NN'), ('upon', 'IN'), ('bed', 'NN'), ('.', '.')]),
#  Tree('S', [('``', '``'), ('god', 'NN'), ('save', 'VBP'), ('us', 'PRP'), ('!', '.'), ("''", "''"), ('exclaims', 'VBZ'), ('mr.', 'FW'), ('tulkinghorn', 'NNP'), ('.', '.'), ('``', '``'), ('he', 'PRP'), ('dead', 'VBD'), ('!', '.'), ("''", "''"), ('krook', 'VB'), ('drop', 'NN'), ('heavy', 'JJ'), ('hand', 'NN'), ('taken', 'VBN'), ('suddenly', 'RB'), ('arm', 'JJ'), ('swing', 'NN')]),
#  Tree('S', [('look', 'VB'), ('one', 'CD'), ('another', 'DT'), ('moment', 'NN'), ('.', '.')]),
#  Tree('S', [('``', '``'), ('send', 'VB'), ('doctor', 'NN'), ('!', '.'), ('call', 'NN'), ('miss', 'JJ'), ('flite', 'NN'), ('stairs', 'NNS'), (',', ','), ('sir', 'NN'), ('.', '.'), ('here', 'RB'), ("'s", 'VBZ'), ('poison', 'NN'), ('call', 'NN'), ('flite', 'NN'), (',', ','), ('you', 'PRP'), ('?', '.'), ("''", "''"), ('say', 'VBP'), ('krook', 'NN'), (',', ','), ('lean', 'JJ'), ('hand', 'NN'), ('spread', 'NN'), ('body', 'NN'), ('like', 'IN'), ('wings', 'NNS'), ('.', '.')]),
#  Tree('S', [('mr.', 'NN'), ('tulkinghorn', 'JJ'), ('hurry', 'VBZ'), ('landing', 'VBG'), ('calls', 'NNS'), (',', ','), ('``', '``'), ('miss', 'JJ'), ('flite', 'NN'), ('!', '.'), ('flite', 'NN'), ('!', '.'), ('make', 'VB'), ('haste', 'NN'), (',', ','), ('here', 'RB'), (',', ','), ('whoever', 'WP'), ('are', 'VBP'), ('!', '.'), ('flite', 'JJ'), ('!', '.'), ("''", "''"), ('krook', 'NN'), ('follows', 'VBZ'), ('eyes', 'NNS'), (',', ','), ('find', 'VBP'), ('opportunity', 'NN'), ('steal', 'VBP'), ('old', 'JJ'), ('portmanteau', 'NN'), ('steal', 'NN'), ('back', 'RB'), ('again', 'RB'), ('.', '.')]),
#  Tree('S', [('``', '``'), ('run', 'NN'), (',', ','), ('flite', 'RB'), (',', ','), ('nearest', 'JJS'), ('doctor', 'NN'), ('!', '.'), Tree('PERSON', [('mr.', 'NN')]), ('krook', 'NNP'), ('address', 'VBZ'), ('crazy', 'JJ'), ('little', 'JJ'), ('woman', 'NN'), ('female', 'JJ'), ('lodger', 'NN'), (',', ','), ('appears', 'VBZ'), ('vanishes', 'NNS'), ('breath', 'NN'), (',', ','), ('soon', 'RB'), ('return', 'VB'), ('accompanied', 'JJ'), ('medical', 'JJ'), ('man', 'NN'), ('brought', 'VBD'), ('dinner', 'NN'), (',', ','), ('upper', 'JJ'), ('lip', 'NN'), ('broad', 'JJ'), ('tongue', 'NN'), ('.', '.')]),
#  Tree('S', [('``', '``'), ('ey', 'NN'), ('!', '.'), ('bless', 'JJ'), ('heart', 'NN'), ('say', 'VBP'), ('medical', 'JJ'), ('man', 'NN'), (',', ','), ('looking', 'VBG'), ('moment', 'NN'), ("'s", 'POS'), ('examination', 'NN'), ('.', '.'), ('``', '``'), ('he', 'PRP'), ("'s", 'VBZ'), ('dead', 'JJ'), ('phairy', 'NN'), ('!', '.'), ("''", "''")]),
#  ...]

# %%
## MT - takes ~ 3 minutes to run this kernel
# create tf-idf matrix
# how important a word is to a document
textVal = data.text.values.astype('str')
vectorizer = TfidfVectorizer()
vectorizer.fit(textVal)
X = vectorizer.transform (textVal).toarray()
names = vectorizer.get_feature_names()
tfidf_dataframe = pd.DataFrame(X, columns = names)

# %%
## MT - Export to .xlsx file

while True:
    print('filename: ')
    name = input() + ".xlsx"
    if os.path.isfile(name):
        print("file already exists")
        continue
    else:
        writer = pd.ExcelWriter(name, engine='xlsxwriter')
        print("creating...")
        break

# To print TF-IDF
tfidf_dataframe.to_excel(writer)

writer.save()
print("complete")
# Out:
# filename:
# tf-idf_test-code
# creating...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-62-1ff67e1a5d7c> in <module>
#      13
#      14 # To print TF-IDF
# ---> 15 tfidf_dataframe.to_excel(writer)
#      16
#      17 writer.save()
#
# c:\users\matay\appdata\local\programs\python\python38\lib\site-packages\pandas\core\generic.py in to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes)
#    2162         from pandas.io.formats.excel import ExcelFormatter
#    2163
# -> 2164         formatter = ExcelFormatter(
#    2165             df,
#    2166             na_rep=na_rep,
#
# c:\users\matay\appdata\local\programs\python\python38\lib\site-packages\pandas\io\formats\excel.py in __init__(self, df, na_rep, float_format, cols, header, index, index_label, merge_cells, inf_rep, style_converter)
#     384         if hasattr(df, "render"):
#     385             self.styler = df
# --> 386             df = df.data
#     387             if style_converter is None:
#     388                 style_converter = CSSToExcelConverter()
#
# c:\users\matay\appdata\local\programs\python\python38\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'data'
